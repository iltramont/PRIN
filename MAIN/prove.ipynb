# %%
import constants
import model_utils
from pprint import pprint

# %%
pprint(constants.Annotations.model_json_schema(by_alias=True)['$defs'])
# Out:
# {'CoinvolgimentoFasciaMesorettale': {'enum': ['no', 'si'],
#                                      'title': 'CoinvolgimentoFasciaMesorettale',
#                                      'type': 'string'},
#  'CoinvolgimentoRiflessionePeritoneale': {'enum': ['no', 'si'],
#                                           'title': 'CoinvolgimentoRiflessionePeritoneale',
#                                           'type': 'string'},
#  'DepositiTumorali': {'enum': ['no', 'si'],
#                       'title': 'DepositiTumorali',
#                       'type': 'string'},
#  'EMVI': {'enum': ['-', '+'], 'title': 'EMVI', 'type': 'string'},
#  'InfiltrazioneOrganiDettagli': {'enum': ['pavimento_pelvico', 'altro'],
#                                  'title': 'InfiltrazioneOrganiDettagli',
#                                  'type': 'string'},
#  'InfiltrazioneOrganiExtra': {'enum': ['no', 'si'],
#                               'title': 'InfiltrazioneOrganiExtra',
# ...
