# %% [markdown]
# # Preliminar Exploratory Data Analysis

# %% [markdown]
# # Preliminari

# %%
import pandas as pd
import os
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import json
import ast
from pprint import pprint

# %%
# Parametri
RAW_DATA_FILE_NAME = 'base.tumoreprimitivo_finale.csv'

# %%
# Set plot style
plt.style.use('ggplot')
#sns.set_palette('hls')
base_dir = Path.cwd().parent
print(f'{base_dir = }')
# Out:
# base_dir = WindowsPath('c:/Users/lucat/PythonRepositories/PRIN')

# %% [markdown]
# # Load Data

# %%
# Get data
data_path = base_dir / 'data' / RAW_DATA_FILE_NAME
data = pd.read_csv(data_path)
data.sort_values(by='id', inplace=True, ignore_index=True)
print(f'{data.shape = }')
display(data.head(2))
pprint(data.iloc[0])
# Out:
# data.shape = (343, 45)
#    id       profile discrepanze_rilevate motivazioni_discrepanze  \
# 0  44   IlariaNacci          ['nessuna']                 nessuna
# 1  46  GuidoImbemba          ['nessuna']                 nessuna
#
#          radiologist  patient_id sesso data_nascita interpretazioni  \
# 0            Barbaro     5667889     M   1976-04-12       dsfgsfsgf
# 1  Guerrieri Daniele      236893     F   1937-10-08             NaN
#
#                                          report_text  ...  \
# 0  RM SCAVO PELVICO (S/C MDC)\nEsame eseguito med...  ...
# 1  NEL RETTO MEDIO, A CIRCA 7 CM DAL MARGINE ANAL...  ...
#
#   coinvolgimento_fascia_mesorettale  distanza_minima_fascia_ore  \
# 0                                si                         NaN
# 1                                no                         NaN
#
#    linfonodi_sospetti  numero_linfonodi_non_conosciuto  \
# 0                 6.0                            False
# 1                 0.0                             True
#
#                                   sedi_locoregionali  sedi_non_locoregionali  \
# 0                                                 []                      []
# 1  ['mesorettali', 'sacrali', 'otturatori', 'rett...                      []
#
#    depositi_tumorali  numero_depositi emvi_esteso    status
# 0                 si              0.0          no  complete
# 1                 no              0.0          no  complete
#
# [2 rows x 45 columns]
# id                                                                                       44
# profile                                                                         IlariaNacci
# discrepanze_rilevate                                                            ['nessuna']
# motivazioni_discrepanze                                                             nessuna
# radiologist                                                                         Barbaro
# patient_id                                                                          5667889
# sesso                                                                                     M
# data_nascita                                                                     1976-04-12
# interpretazioni                                                                   dsfgsfsgf
# report_text                               RM SCAVO PELVICO (S/C MDC)\nEsame eseguito med...
# morfologia                                                                              NaN
# ore_inizio                                                                              NaN
# ore_fine                                                                                NaN
# dimensione_dll                                                                          NaN
# dimensione_dap                                                                          NaN
# spessore_parietale                                                                      NaN
# estensione_cranio_caudale                                                               NaN
# distanza_oai                                                                            NaN
# posizione                                                                               NaN
# posizione_multiple                                                                       []
# carcinosi_peritoneale                                                                    no
# lesioni_ossee                                                                            si
# stadio_T                                                                                T4b
# stadio_N                                                                                N1c
# stadio_N1c                                                                            False
# mrf                                                                                       +
# emvi                                                                                      -
# metastasi                                                                                M1
# motivazioni_extra                                                                   nessuna
# riflessione_peritoneale_anteriore                                                       NaN
# infiltrazione_tessuto_adiposo                                                   si_5mm_plus
# infiltrazione_sfinteri                                                interno_piano_esterno
# infiltrazione_organi_extra                                                               no
# infiltrazione_organi_dettagli                                               [object Object]
# coinvolgimento_riflessione_peritoneale                                              rischio
# coinvolgimento_fascia_mesorettale                                                        si
# distanza_minima_fascia_ore                                                              NaN
# linfonodi_sospetti                                                                      6.0
# numero_linfonodi_non_conosciuto                                                       False
# sedi_locoregionali                                                                       []
# sedi_non_locoregionali                                                                   []
# depositi_tumorali                                                                        si
# numero_depositi                                                                         0.0
# emvi_esteso                                                                              no
# status                                                                             complete
# Name: 0, dtype: object

# %%
# Referti poco chiari. Sono quelli che hanno la stringa "escludere".
for i, r in data[data['interpretazioni'].str.contains("escludere", case=False, na=False)].iterrows():
    print(f"*--- id referto: {r['id']}\ninterpretazione: {r['interpretazioni']}\n{100*'-'}")
# Out:
# *--- id referto: 171
# interpretazione: FORSE DA ESCLUDERE; REFERTO NON CHIARO
#
# la formazione nodulare è digitazione della neoplasia o linfonodo? in base a questo va compilato.
#
# non si può sapere se non rivedendo immagini, anche per linfonodi non è chiaro se sono sospetti o no,
# ----------------------------------------------------------------------------------------------------
# *--- id referto: 259
# interpretazione: POCHE INFO; FORSE DA ESCLUDERE
#
# 55 mm che misura è?
# credo possa riferirsi a diametro assiale massimo
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Pulisci dati

# %%
# Rimuovi righe duplicate
print(f'Shape iniziale: {data.shape}')

# Intere righe duplicate. Keep last perchè i report hanno id crescente
duplicati = data.iloc[:, 1:].duplicated(keep='last')
print(f'Numero righe duplicate: {duplicati.sum()}')

data_clean = data[duplicati == False]
print('Righe doppie eliminate')
# Out:
# Shape iniziale: (343, 45)
# Numero righe duplicate: 2
# Righe doppie eliminate

# %%
# Rimuovi righe con report duplicati
duplicati = data_clean['report_text'].duplicated(keep='last')
righe_report_duplicato = data_clean[duplicati]
print(f'Numero righe con stesso referto: {duplicati.sum()}')

data_clean = data_clean[duplicati == False]
print('Righe eliminate')

data_clean.reset_index(inplace=True, drop=True)

print(f'{data_clean.shape = }')
# Out:
# Numero righe con stesso referto: 22
# Righe eliminate
# data_clean.shape = (319, 45)

# %%
# !!! Anomalia. Numero depositi non può essere negativo.
data_clean[
    (data_clean['numero_depositi'] < 0)
    ][
         ['id', 'profile', 'depositi_tumorali', 'numero_depositi']
    ]
# Out:
#       id            profile depositi_tumorali  numero_depositi
# 38    95       GuidoImbemba                no             -1.0
# 40    98       GuidoImbemba                no             -1.0
# 70   132  PietroPaoloAzzaro                no             -1.0
# 98   171       GuidoImbemba                no             -1.0
# 100  173       GuidoImbemba                no             -1.0

# %%
# Sostituiamo valore -1 con 0 per la colonna numero depositi
data_clean.loc[data_clean['numero_depositi'] == -1.0, 'numero_depositi'] = 0.0

# %%
# !!! Anomalia. Se i linfonodi sospetti sono 0, non possso avere le sedi valorizzate.
data_clean[
    (data_clean['linfonodi_sospetti'] == 0) &
    (data_clean['numero_linfonodi_non_conosciuto'] == False) &
    (data_clean['sedi_locoregionali'] != '[]')
    ][
         ['id', 'profile', 'numero_linfonodi_non_conosciuto', 'linfonodi_sospetti', 'sedi_locoregionali']
    ]
# Out:
#       id            profile  numero_linfonodi_non_conosciuto  \
# 7     55  PietroPaoloAzzaro                            False
# 48   107  PietroPaoloAzzaro                            False
# 60   120  PietroPaoloAzzaro                            False
# 63   125  PietroPaoloAzzaro                            False
# 66   128  PietroPaoloAzzaro                            False
# 67   129  PietroPaoloAzzaro                            False
# 68   130  PietroPaoloAzzaro                            False
# 69   131  PietroPaoloAzzaro                            False
# 70   132  PietroPaoloAzzaro                            False
# 71   133  PietroPaoloAzzaro                            False
# 72   134  PietroPaoloAzzaro                            False
# 139  212  PietroPaoloAzzaro                            False
# 220  309  PietroPaoloAzzaro                            False
# 221  310  PietroPaoloAzzaro                            False
# 222  311  PietroPaoloAzzaro                            False
# 231  322  PietroPaoloAzzaro                            False
# 236  329  PietroPaoloAzzaro                            False
# 238  331  PietroPaoloAzzaro                            False
# 240  333  PietroPaoloAzzaro                            False
# 242  335  PietroPaoloAzzaro                            False
# 245  338  PietroPaoloAzzaro                            False
# 252  346  PietroPaoloAzzaro                            False
# 254  348  PietroPaoloAzzaro                            False
# 262  356  PietroPaoloAzzaro                            False
# 274  368  PietroPaoloAzzaro                            False
# 277  371  PietroPaoloAzzaro                            False
# 278  372  PietroPaoloAzzaro                            False
# 281  375  PietroPaoloAzzaro                            False
# 287  382  PietroPaoloAzzaro                            False
# 291  387  PietroPaoloAzzaro                            False
# 294  392  PietroPaoloAzzaro                            False
# 297  395  PietroPaoloAzzaro                            False
# 298  396  PietroPaoloAzzaro                            False
# 299  397  PietroPaoloAzzaro                            False
# 302  400  PietroPaoloAzzaro                            False
# 303  401  PietroPaoloAzzaro                            False
# 307  409  PietroPaoloAzzaro                            False
# 308  410  PietroPaoloAzzaro                            False
# 309  411  PietroPaoloAzzaro                            False
# 310  412  PietroPaoloAzzaro                            False
# 311  413  PietroPaoloAzzaro                            False
# 312  415  PietroPaoloAzzaro                            False
# 313  416  PietroPaoloAzzaro                            False
#
#      linfonodi_sospetti                                 sedi_locoregionali
# 7                   0.0               ['mesorettali', 'rettali_superiori']
# 48                  0.0               ['mesorettali', 'rettali_superiori']
# 60                  0.0  ['mesorettali', 'otturatori', 'iliaci_interni'...
# 63                  0.0                  ['mesorettali', 'iliaci_interni']
# 66                  0.0                                    ['mesorettali']
# 67                  0.0               ['mesorettali', 'rettali_superiori']
# 68                  0.0                      ['mesorettali', 'otturatori']
# 69                  0.0               ['mesorettali', 'rettali_superiori']
# 70                  0.0  ['mesorettali', 'otturatori', 'rettali_superio...
# 71                  0.0                                    ['mesorettali']
# 72                  0.0                                    ['mesorettali']
# 139                 0.0    ['mesorettali', 'otturatori', 'iliaci_interni']
# 220                 0.0               ['mesorettali', 'rettali_superiori']
# 221                 0.0           ['mesorettali', 'mesenterici_inferiori']
# 222                 0.0  ['mesorettali', 'mesenterici_inferiori', 'rett...
# 231                 0.0           ['mesorettali', 'mesenterici_inferiori']
# 236                 0.0           ['mesorettali', 'mesenterici_inferiori']
# 238                 0.0  ['mesorettali', 'otturatori', 'rettali_superio...
# 240                 0.0                                    ['mesorettali']
# 242                 0.0           ['mesorettali', 'sacrali', 'otturatori']
# 245                 0.0               ['mesorettali', 'rettali_superiori']
# 252                 0.0               ['mesorettali', 'rettali_superiori']
# 254                 0.0                                        ['sacrali']
# 262                 0.0               ['mesorettali', 'rettali_superiori']
# 274                 0.0  ['mesorettali', 'otturatori', 'rettali_superio...
# 277                 0.0               ['mesorettali', 'rettali_superiori']
# 278                 0.0    ['mesorettali', 'sacrali', 'rettali_superiori']
# 281                 0.0               ['mesorettali', 'rettali_superiori']
# 287                 0.0               ['mesorettali', 'rettali_superiori']
# 291                 0.0               ['mesorettali', 'rettali_superiori']
# 294                 0.0                  ['mesorettali', 'iliaci_interni']
# 297                 0.0                                    ['mesorettali']
# 298                 0.0               ['mesorettali', 'rettali_superiori']
# 299                 0.0  ['mesorettali', 'otturatori', 'sacrali', 'rett...
# 302                 0.0               ['mesorettali', 'rettali_superiori']
# 303                 0.0                                    ['mesorettali']
# 307                 0.0                                    ['mesorettali']
# 308                 0.0                                    ['mesorettali']
# 309                 0.0               ['mesorettali', 'rettali_superiori']
# 310                 0.0                                     ['otturatori']
# 311                 0.0  ['mesorettali', 'rettali_superiori', 'mesenter...
# 312                 0.0                                    ['mesorettali']
# 313                 0.0                                     ['otturatori']

# %% [markdown]
# Dando un'occhiata ai referti si osserva come il modo corretto per risolvere l'anomalia è quello di valorizzare a True il campo numero_linfonodi_non_conosciuto.

# %%
data_clean.loc[
    (data_clean['linfonodi_sospetti'] == 0) &
    (data_clean['numero_linfonodi_non_conosciuto'] == False) &
    (data_clean['sedi_locoregionali'] != '[]')
    , 'numero_linfonodi_non_conosciuto'
    ] = True

# %%
# !!! anomalia
data_clean[
    (data_clean['infiltrazione_organi_dettagli'] > '') &
    (data_clean['infiltrazione_organi_extra'] == 'no')
    ][
        ['id', 'profile', 'infiltrazione_organi_dettagli', 'infiltrazione_organi_extra']
    ]
# Out:
#       id            profile  \
# 0     44        IlariaNacci
# 2     47       GuidoImbemba
# 3     51       GuidoImbemba
# 5     53  PietroPaoloAzzaro
# 6     54  PietroPaoloAzzaro
# 7     55  PietroPaoloAzzaro
# 8     56  PietroPaoloAzzaro
# 9     57  PietroPaoloAzzaro
# 11    59       GuidoImbemba
# 13    62       GuidoImbemba
# 16    66       GuidoImbemba
# 17    67       GuidoImbemba
# 24    76       GuidoImbemba
# 45   104       GuidoImbemba
# 47   106  PietroPaoloAzzaro
# 48   107  PietroPaoloAzzaro
# 69   131  PietroPaoloAzzaro
# 70   132  PietroPaoloAzzaro
# 71   133  PietroPaoloAzzaro
# 74   136  PietroPaoloAzzaro
# 75   137  PietroPaoloAzzaro
# 76   138  PietroPaoloAzzaro
# 94   167       GuidoImbemba
# 122  195  PietroPaoloAzzaro
# 177  250       GuidoImbemba
# 180  254       GuidoImbemba
# 188  262       GuidoImbemba
# 239  332  PietroPaoloAzzaro
# 268  362  PietroPaoloAzzaro
#
#                          infiltrazione_organi_dettagli  \
# 0                                      [object Object]
# 2                         {'pavimento_pelvico': False}
# 3                         {'pavimento_pelvico': False}
# 5                                      {'utero': True}
# 6    {'altro': 'lungo i vasi emorroidari superiori....
# 7    {'altro': 'lungo i vasi emorroidari superiori....
# 8    {'altro': 'lungo i vasi emorroidari superiori....
# 9    {'altro': 'lungo i vasi emorroidari superiori....
# 11                                       {'altro': ''}
# 13                                       {'altro': ''}
# 16                                       {'altro': ''}
# 17                                       {'altro': ''}
# 24                        {'pavimento_pelvico': False}
# 45                        {'pavimento_pelvico': False}
# 47   {'altro': 'lungo i vasi emorroidari superiori....
# 48   {'altro': 'lungo i vasi emorroidari superiori....
# 69                                     {'sacro': True}
# 70                                     {'sacro': True}
# 71                                     {'sacro': True}
# 74   {'altro': 'infiltrazione della prostata da par...
# 75   {'altro': 'infiltrazione della prostata da par...
# 76   {'altro': 'infiltrazione della prostata da par...
# 94                        {'pavimento_pelvico': False}
# 122          {'altro': 'lesioni secondarie al fegato'}
# 177                                   {'sacro': False}
# 180                                   {'sacro': False}
# 188                                      {'altro': ''}
# 239           {'altro': 'vescichetta seminale destra'}
# 268  {'altro': "muscolo elevatore dell'ano", 'pavim...
#
#     infiltrazione_organi_extra
# 0                           no
# 2                           no
# 3                           no
# 5                           no
# 6                           no
# 7                           no
# 8                           no
# 9                           no
# 11                          no
# 13                          no
# 16                          no
# 17                          no
# 24                          no
# 45                          no
# 47                          no
# 48                          no
# 69                          no
# 70                          no
# 71                          no
# 74                          no
# 75                          no
# 76                          no
# 94                          no
# 122                         no
# 177                         no
# 180                         no
# 188                         no
# 239                         no
# 268                         no

# %%
# Sostituiamo i valore con None nella colonna dei dettagli degli organi coinvolti pechè altri valori non sono compatibili
# con "no" nella colonna infiltrazione_organi_extra.
data_clean.loc[
    (data_clean['infiltrazione_organi_dettagli'] > '') &
    (data_clean['infiltrazione_organi_extra'] == 'no')
    , 'infiltrazione_organi_dettagli'
    ] = None

# %%
# creazione nuova colonna "sedi_linfonodi_sospetti"
sedi_linfonodi = []
for s1, s2 in zip(data_clean.sedi_locoregionali, data_clean.sedi_non_locoregionali):
    sedi_linfonodi.append(str(ast.literal_eval(s1) + ast.literal_eval(s2)))
data_clean['sedi_linfonodi'] = sedi_linfonodi
data_clean[['sedi_locoregionali', 'sedi_non_locoregionali', 'sedi_linfonodi']].head(15)
# Out:
#                                    sedi_locoregionali  \
# 0                                                  []
# 1   ['mesorettali', 'sacrali', 'otturatori', 'rett...
# 2                                                  []
# 3                ['mesorettali', 'rettali_superiori']
# 4                         ['inguinali_sotto_dentata']
# 5                                     ['mesorettali']
# 6                       ['mesorettali', 'otturatori']
# 7                ['mesorettali', 'rettali_superiori']
# 8                       ['mesorettali', 'otturatori']
# 9   ['mesorettali', 'iliaci_interni', 'otturatori'...
# 10    ['mesorettali', 'iliaci_interni', 'otturatori']
# 11                                     ['otturatori']
# 12                                    ['mesorettali']
# 13                                                 []
# 14                                    ['mesorettali']
#
#                  sedi_non_locoregionali  \
# 0                                    []
# 1                                    []
# 2                                    []
# 3                                    []
# 4                                    []
# 5   ['iliaci_esterni', 'iliaci_comuni']
# 6                    ['iliaci_esterni']
# 7                    ['iliaci_esterni']
# 8                                    []
# 9                                    []
# 10                                   []
# 11                                   []
# 12                                   []
# 13                                   []
# 14                                   []
#
#                                        sedi_linfonodi
# 0                                                  []
# 1   ['mesorettali', 'sacrali', 'otturatori', 'rett...
# 2                                                  []
# 3                ['mesorettali', 'rettali_superiori']
# 4                         ['inguinali_sotto_dentata']
# 5   ['mesorettali', 'iliaci_esterni', 'iliaci_comu...
# 6     ['mesorettali', 'otturatori', 'iliaci_esterni']
# 7   ['mesorettali', 'rettali_superiori', 'iliaci_e...
# 8                       ['mesorettali', 'otturatori']
# 9   ['mesorettali', 'iliaci_interni', 'otturatori'...
# 10    ['mesorettali', 'iliaci_interni', 'otturatori']
# 11                                     ['otturatori']
# 12                                    ['mesorettali']
# 13                                                 []
# 14                                    ['mesorettali']

# %% [markdown]
# # Analisi preliminari delle colonne

# %%
print(data_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 46 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      319 non-null    int64
#  1   profile                                 319 non-null    object
#  2   discrepanze_rilevate                    319 non-null    object
#  3   motivazioni_discrepanze                 319 non-null    object
#  4   radiologist                             293 non-null    object
#  5   patient_id                              319 non-null    int64
#  6   sesso                                   317 non-null    object
#  7   data_nascita                            318 non-null    object
#  8   interpretazioni                         112 non-null    object
#  9   report_text                             319 non-null    object
#  10  morfologia                              317 non-null    object
#  11  ore_inizio                              78 non-null     float64
#  12  ore_fine                                78 non-null     float64
#  13  dimensione_dll                          17 non-null     float64
#  14  dimensione_dap                          13 non-null     float64
#  15  spessore_parietale                      52 non-null     float64
#  16  estensione_cranio_caudale               303 non-null    float64
#  17  distanza_oai                            268 non-null    float64
#  18  posizione                               170 non-null    object
#  19  posizione_multiple                      319 non-null    object
#  20  carcinosi_peritoneale                   8 non-null      object
#  21  lesioni_ossee                           9 non-null      object
#  22  stadio_T                                309 non-null    object
#  23  stadio_N                                318 non-null    object
#  24  stadio_N1c                              319 non-null    bool
#  25  mrf                                     206 non-null    object
#  26  emvi                                    143 non-null    object
#  27  metastasi                               48 non-null     object
#  28  motivazioni_extra                       319 non-null    object
#  29  riflessione_peritoneale_anteriore       170 non-null    object
#  30  infiltrazione_tessuto_adiposo           306 non-null    object
#  31  infiltrazione_sfinteri                  111 non-null    object
#  32  infiltrazione_organi_extra              230 non-null    object
#  33  infiltrazione_organi_dettagli           75 non-null     object
#  34  coinvolgimento_riflessione_peritoneale  85 non-null     object
#  35  coinvolgimento_fascia_mesorettale       153 non-null    object
#  36  distanza_minima_fascia_ore              36 non-null     float64
#  37  linfonodi_sospetti                      311 non-null    float64
#  38  numero_linfonodi_non_conosciuto         319 non-null    bool
#  39  sedi_locoregionali                      319 non-null    object
#  40  sedi_non_locoregionali                  319 non-null    object
#  41  depositi_tumorali                       151 non-null    object
#  42  numero_depositi                         316 non-null    float64
#  43  emvi_esteso                             319 non-null    object
#  44  status                                  319 non-null    object
#  45  sedi_linfonodi                          319 non-null    object
# dtypes: bool(2), float64(10), int64(2), object(32)
# memory usage: 110.4+ KB
# None

# %%
# Fill NaN for plotting purposes
data_plot = data_clean.fillna('NaN')
data_ilaria = data_plot[data_plot['profile'] == 'IlariaNacci']
data_plot = data_plot.drop(index=data_plot[data_plot['profile'] == 'IlariaNacci'].index)
data_x = pd.concat([data_plot, data_ilaria])

# %%
# Radiologi che hanno scritto i referti.
data_x['radiologist'].value_counts()
# Out:
# radiologist
# BARBARO PROF. BRUNELLA           80
# Barbaro Brunella                 73
# NaN                              26
# BRIZI DOTT. MARIA GABRIELLA      16
# DE GAETANO DOTT. ANNA MARIA      13
# Brizi Maria Gabriella            12
# De Gaetano Anna Maria            11
# Macis Giuseppe                    9
# MACIS DOTT. GIUSEPPE              8
# Summaria Vincenzo                 6
# GUI DOTT. BENEDETTA               5
# Genco Enza                        5
# GENCO DOTT.SSA ENZA               5
# MINORDI DOTT. LAURA MARIA         4
# D'AMBRA DOTT.SSA GIULIA           3
# RODOLFINO DOTT.SSA ELENA          3
# Minordi Laura Maria               3
# MANFREDI PROF. RICCARDO           3
# AVESANI DOTT. GIACOMO             3
# Panico Camilla                    3
# Guerrieri Daniele                 2
# Manfredi Riccardo                 2
# Avesani Giacomo                   2
# Di Paola Valerio                  2
# Carano Davide                     2
# Rodolfino Elena                   2
# Micco' Maura                      1
# Petta Federica                    1
# NATALE PROF. LUIGI                1
# Giuliani Michela                  1
# Persiani Salvatore                1
# Di Marco Margo'                   1
# Arcioni Daniel                    1
# PANICO DOTT.SSA CAMILLA           1
# MICCO' DOTT.SSA MAURA             1
# FARCHIONE DOTT.SSA ALESSANDRA     1
# Perla Daniele                     1
# Gui Benedetta                     1
# Farchione Alessandra              1
# Bianco Nicola Carlo               1
# BONOMO PROF. LORENZO              1
# Barbaro                           1
# Name: count, dtype: int64

# %%
columns_plot = ['profile', 'discrepanze_rilevate', 'motivazioni_discrepanze', 'sesso', 'motivazioni_extra', 'status']
#columns_plot = ['profile', 'status']
hue_column = 'profile'

include_ilaria = False
print_statistics = False

n_columns = min(3, len(columns_plot))
n_rows, r = divmod(len(columns_plot), n_columns)
if r != 0:
    n_rows += 1

fig, axes = plt.subplots(n_rows, n_columns, figsize=(n_columns*7, n_rows*3))
fig.suptitle("Medical staf's info distributions by profile", fontsize='xx-large')

for i, col in enumerate(columns_plot):
    if n_rows == 1:
        ax = axes[i]
    else:
        ax=axes[i//n_columns][i%n_columns]
    if include_ilaria:
        sns.countplot(data=data_x, x=col, order=data_x[col].value_counts().index, ax=ax, hue=hue_column)
    else:
        sns.countplot(data=data_plot, x=col, order=data_plot[col].value_counts().index, ax=ax, hue=hue_column)
    # Add values on top of bars
    for p in ax.patches:
        y_text = int(p.get_height())
        x_text = p.get_x() + p.get_width() / 2
        ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')

plt.tight_layout()
#plt.savefig("distribuzione_status_per_annotatore.png", dpi=300, bbox_inches='tight', transparent=False)
plt.show()

if print_statistics:
    columns = ['profile', 'discrepanze_rilevate', 'motivazioni_discrepanze', 'radiologist', 'sesso', 'motivazioni_extra', 'status']
    print(f'{len(columns) = }\n')
    for col in columns:
        print(data_clean[col].value_counts().to_frame().T)
        print("\n")

# %%
columns_plot = ['profile', 'morfologia', 'infiltrazione_tessuto_adiposo', 'coinvolgimento_fascia_mesorettale',
                'carcinosi_peritoneale', 'riflessione_peritoneale_anteriore', 'coinvolgimento_riflessione_peritoneale',
                'stadio_T', 'stadio_N', 'stadio_N1c',
                'mrf', 'emvi', 'metastasi',
                'infiltrazione_sfinteri', 'infiltrazione_organi_extra',
                'linfonodi_sospetti', 'numero_linfonodi_non_conosciuto', 'lesioni_ossee',
                'depositi_tumorali', 'numero_depositi', 'emvi_esteso']

#hue_column = 'depositi_tumorali'
#columns_plot = [hue_column] + columns_plot

n_columns = 3
n_rows, r = divmod(len(columns_plot), n_columns)
if r != 0:
    n_rows += 1
    
fig, axes = plt.subplots(n_rows, n_columns, figsize=(n_columns*7, n_rows*3))
fig.suptitle("Count values", fontsize='xx-large')

for i, col in enumerate(columns_plot):
    ax=axes[i//n_columns][i%n_columns]
    sns.countplot(data=data_plot, x=col, order=data_plot[col].value_counts().index, ax=ax, hue=hue_column)
    # Add values on top of bars
    for p in ax.patches:
        y_text = int(p.get_height())
        x_text = p.get_x() + p.get_width() / 2
        ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')

plt.tight_layout()
#plt.savefig("distribuzione_featurse_per_annotatore.png", dpi=300, bbox_inches='tight', transparent=False)
plt.show()

fig, ax = plt.subplots(figsize=(21, 3))
sns.countplot(data=data_plot, x='posizione_multiple', order=data_plot['posizione_multiple'].value_counts().index, ax=ax, hue='profile')
# Add values on top of bars
for p in ax.patches:
    y_text = int(p.get_height())
    x_text = p.get_x() + p.get_width() / 2
    ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(21, 3))
sns.countplot(data=data_plot, x='posizione', order=data_plot['posizione'].value_counts().index, ax=ax, hue='profile')
# Add values on top of bars
for p in ax.patches:
    y_text = int(p.get_height())
    x_text = p.get_x() + p.get_width() / 2
    ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %%
# Analisi posizione, sedi locoregionali, sedi non locoregionali
columns = ['posizione_multiple', 'sedi_locoregionali', 'sedi_non_locoregionali', 'sedi_linfonodi']

possible_values = {col: ['NaN'] for col in columns}

for col in columns:
    for s in data_plot[col].value_counts().index:
        possible_values[col] += ast.literal_eval(s)
    possible_values[col] = list(set(possible_values[col]))    


counts = {
    col: {val: 0 for val in possible_values[col]}
    for col in columns
}
for col in columns:
    for s in data_plot[col]:
        value_list = ast.literal_eval(s)
        for value in possible_values[col]:
            if value in value_list:
                counts[col][value] += 1
        if value_list == []:
            counts[col]['NaN'] += 1
            
            
# Dettagli organi
dettagli_organi = {'NaN'}
altri_organi = set()
for s in data_x.infiltrazione_organi_dettagli.fillna('NaN').value_counts().index:
    if s != 'NaN' and s != 'nan':
        d = ast.literal_eval(s)
        #print('---')
        dettagli_organi.update(d.keys())
        if 'altro' in d:
            altri_organi.add(d['altro'])
            
dettagli_organi_counts = {val: 0 for val in dettagli_organi}
for s in data_x.infiltrazione_organi_dettagli.fillna('NaN'):
    if s == 'NaN' or s == 'nan':
        dettagli_organi_counts['NaN'] += 1
    else:
        d = ast.literal_eval(s)
        for key in dettagli_organi:
            if key in d:
                dettagli_organi_counts[key] += 1

counts['infiltrazione_organi_dettagli'] = dettagli_organi_counts
columns.append('infiltrazione_organi_dettagli')
         
         
n_columns = 2
n_rows, r = divmod(len(columns), n_columns)
if r != 0:
    n_rows += 1
            
fig, axes = plt.subplots(n_rows, n_columns, figsize=(21, n_rows*3))
orientation = 'h'
for i, col in enumerate(columns):
    ax=axes[i//n_columns][i%n_columns]
    series = pd.Series(counts[col], name=col).sort_values(ascending=False)
    sns.barplot(data=series, ax=ax, orient=orientation)
    # Add values on top of bars
    if orientation == 'v':
        for p in ax.patches:
            y_text = int(p.get_height())
            x_text = p.get_x() + p.get_width() / 2
            ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')
    if orientation == 'h':
        for p in ax.patches:
            x_text = p.get_width()
            y_text = p.get_y() + p.get_height() / 2
            ax.text(x=x_text, y=y_text, s=f'{int(x_text)}', va='center', ha='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **We see many anomalies between Guido and Pietro style of annotation. For this reason and also for what Ilaria told us, we will take into consideration only reports annotated by Guido**

# %% [markdown]
# # Guido's rows

# %%
data_clean_guido = data_clean[data_clean['profile'] == 'GuidoImbemba'].copy(deep=True)
data_clean_guido.reset_index(inplace=True, drop=True)
data_plot = data_clean_guido.fillna('NaN')

print(data_clean_guido.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 46 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      144 non-null    int64
#  1   profile                                 144 non-null    object
#  2   discrepanze_rilevate                    144 non-null    object
#  3   motivazioni_discrepanze                 144 non-null    object
#  4   radiologist                             144 non-null    object
#  5   patient_id                              144 non-null    int64
#  6   sesso                                   143 non-null    object
#  7   data_nascita                            144 non-null    object
#  8   interpretazioni                         59 non-null     object
#  9   report_text                             144 non-null    object
#  10  morfologia                              143 non-null    object
#  11  ore_inizio                              57 non-null     float64
#  12  ore_fine                                57 non-null     float64
#  13  dimensione_dll                          12 non-null     float64
#  14  dimensione_dap                          9 non-null      float64
#  15  spessore_parietale                      25 non-null     float64
#  16  estensione_cranio_caudale               135 non-null    float64
#  17  distanza_oai                            132 non-null    float64
#  18  posizione                               97 non-null     object
#  19  posizione_multiple                      144 non-null    object
#  20  carcinosi_peritoneale                   1 non-null      object
#  21  lesioni_ossee                           2 non-null      object
#  22  stadio_T                                140 non-null    object
#  23  stadio_N                                143 non-null    object
#  24  stadio_N1c                              144 non-null    bool
#  25  mrf                                     55 non-null     object
#  26  emvi                                    28 non-null     object
#  27  metastasi                               7 non-null      object
#  28  motivazioni_extra                       144 non-null    object
#  29  riflessione_peritoneale_anteriore       89 non-null     object
#  30  infiltrazione_tessuto_adiposo           132 non-null    object
#  31  infiltrazione_sfinteri                  16 non-null     object
#  32  infiltrazione_organi_extra              142 non-null    object
#  33  infiltrazione_organi_dettagli           34 non-null     object
#  34  coinvolgimento_riflessione_peritoneale  26 non-null     object
#  35  coinvolgimento_fascia_mesorettale       57 non-null     object
#  36  distanza_minima_fascia_ore              7 non-null      float64
#  37  linfonodi_sospetti                      144 non-null    float64
#  38  numero_linfonodi_non_conosciuto         144 non-null    bool
#  39  sedi_locoregionali                      144 non-null    object
#  40  sedi_non_locoregionali                  144 non-null    object
#  41  depositi_tumorali                       79 non-null     object
#  42  numero_depositi                         143 non-null    float64
#  43  emvi_esteso                             144 non-null    object
#  44  status                                  144 non-null    object
#  45  sedi_linfonodi                          144 non-null    object
# dtypes: bool(2), float64(10), int64(2), object(32)
# memory usage: 49.9+ KB
# None

# %%
columns_plot = ['discrepanze_rilevate', 'motivazioni_discrepanze', 'sesso', 'motivazioni_extra', 'status']

print_statistics = False

n_columns = min(3, len(columns_plot))
n_rows, r = divmod(len(columns_plot), n_columns)
if r != 0:
    n_rows += 1

fig, axes = plt.subplots(n_rows, n_columns, figsize=(n_columns*7, n_rows*3))
fig.suptitle("Medical staf's info distributions (Guido)", fontsize='xx-large')

for i, col in enumerate(columns_plot):
    if n_rows == 1:
        ax = axes[i]
    else:
        ax=axes[i//n_columns][i%n_columns]    
    sns.countplot(data=data_plot, x=col, order=data_plot[col].value_counts().index, ax=ax)
    # Add values on top of bars
    for p in ax.patches:
        y_text = int(p.get_height())
        x_text = p.get_x() + p.get_width() / 2
        ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')

plt.tight_layout()
#plt.savefig("distribuzione_status_per_annotatore.png", dpi=300, bbox_inches='tight', transparent=False)
plt.show()

if print_statistics:
    print(f'{len(columns_plot) = }\n')
    for col in columns_plot:
        print(data_plot[col].value_counts().to_frame().T)
        print("\n")

# %%
columns_plot = ['morfologia', 'infiltrazione_tessuto_adiposo', 'coinvolgimento_fascia_mesorettale',
                'carcinosi_peritoneale', 'riflessione_peritoneale_anteriore', 'coinvolgimento_riflessione_peritoneale',
                'stadio_T', 'stadio_N', 'stadio_N1c',
                'mrf', 'emvi', 'metastasi',
                'infiltrazione_sfinteri', 'infiltrazione_organi_extra',
                'linfonodi_sospetti', 'numero_linfonodi_non_conosciuto', 'lesioni_ossee',
                'depositi_tumorali', 'numero_depositi', 'emvi_esteso']

#hue_column = None
#columns_plot = [hue_column] + columns_plot

n_columns = 3
n_rows, r = divmod(len(columns_plot), n_columns)
if r != 0:
    n_rows += 1
    
fig, axes = plt.subplots(n_rows, n_columns, figsize=(n_columns*7, n_rows*3))
fig.suptitle("Count values (Guido)", fontsize='xx-large')

for i, col in enumerate(columns_plot):
    ax=axes[i//n_columns][i%n_columns]
    sns.countplot(data=data_plot, x=col, order=data_plot[col].value_counts().index, ax=ax, hue=hue_column)
    # Add values on top of bars
    for p in ax.patches:
        y_text = int(p.get_height())
        x_text = p.get_x() + p.get_width() / 2
        ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')

plt.tight_layout()
#plt.savefig("distribuzione_featurse_per_annotatore.png", dpi=300, bbox_inches='tight', transparent=False)
plt.show()

# %%
# Analisi posizione, sedi locoregionali, sedi non locoregionali
columns = ['posizione_multiple', 'sedi_locoregionali', 'sedi_non_locoregionali', 'sedi_linfonodi']

possible_values = {col: ['NaN'] for col in columns}

for col in columns:
    for s in data_plot[col].value_counts().index:
        possible_values[col] += ast.literal_eval(s)
    possible_values[col] = list(set(possible_values[col]))    


counts = {
    col: {val: 0 for val in possible_values[col]}
    for col in columns
}
for col in columns:
    for s in data_plot[col]:
        value_list = ast.literal_eval(s)
        for value in possible_values[col]:
            if value in value_list:
                counts[col][value] += 1
        if value_list == []:
            counts[col]['NaN'] += 1
            
            
# Dettagli organi
dettagli_organi = {'NaN'}
altri_organi = set()
for s in data_clean_guido.infiltrazione_organi_dettagli.fillna('NaN').value_counts().index:
    if s != 'NaN' and s != 'nan':
        d = ast.literal_eval(s)
        #print('---')
        dettagli_organi.update(d.keys())
        if 'altro' in d:
            altri_organi.add(d['altro'])
            
dettagli_organi_counts = {val: 0 for val in dettagli_organi}
for s in data_clean_guido.infiltrazione_organi_dettagli.fillna('NaN'):
    if s == 'NaN' or s == 'nan':
        dettagli_organi_counts['NaN'] += 1
    else:
        d = ast.literal_eval(s)
        for key in dettagli_organi:
            if key in d:
                dettagli_organi_counts[key] += 1

counts['infiltrazione_organi_dettagli'] = dettagli_organi_counts
columns.append('infiltrazione_organi_dettagli')
         
         
n_columns = 2
n_rows, r = divmod(len(columns), n_columns)
if r != 0:
    n_rows += 1
            
fig, axes = plt.subplots(n_rows, n_columns, figsize=(21, n_rows*3))
orientation = 'h'
for i, col in enumerate(columns):
    ax=axes[i//n_columns][i%n_columns]
    series = pd.Series(counts[col], name=col).sort_values(ascending=False)
    sns.barplot(data=series, ax=ax, orient=orientation)
    # Add values on top of bars
    if orientation == 'v':
        for p in ax.patches:
            y_text = int(p.get_height())
            x_text = p.get_x() + p.get_width() / 2
            ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')
    if orientation == 'h':
        for p in ax.patches:
            x_text = p.get_width()
            y_text = p.get_y() + p.get_height() / 2
            ax.text(x=x_text, y=y_text, s=f'{int(x_text)}', va='center', ha='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Idea: uniamo sedi locoregionali e non locoregionali e manteniamo solo alcune classi: mesorettali, rettali_superiori, NaN, otturatori, iliaci. I restanti li metteremo in "altro".
#
# Per quanto riguarda i dettagli dell'infiltrazione organi, teniamo solo le classi NaN, pavimento_pelvico, altro.

# %% [markdown]
# # Aggregazione / modifica delle colonne

# %%
palette_corrente = plt.rcParams['axes.prop_cycle'].by_key()['color']
print(palette_corrente)
display(sns.color_palette(palette_corrente))
new_color = palette_corrente[-2]
# Out:
# ['#E24A33', '#348ABD', '#988ED5', '#777777', '#FBC15E', '#8EBA42', '#FFB5B8']
# [(0.8862745098039215, 0.2901960784313726, 0.2),
#  (0.20392156862745098, 0.5411764705882353, 0.7411764705882353),
#  (0.596078431372549, 0.5568627450980392, 0.8352941176470589),
#  (0.4666666666666667, 0.4666666666666667, 0.4666666666666667),
#  (0.984313725490196, 0.7568627450980392, 0.3686274509803922),
#  (0.5568627450980392, 0.7294117647058823, 0.25882352941176473),
#  (1.0, 0.7098039215686275, 0.7215686274509804)]

# %%
# Dettagli infiltrazione organi
infiltrazione_organi_dettagli_new = []
for s in data_clean_guido.infiltrazione_organi_dettagli.fillna('NaN'):
    dettagli = []
    if s == 'NaN':
        infiltrazione_organi_dettagli_new.append(str(dettagli))
    else:
        d = ast.literal_eval(s)
        if 'pavimento_pelvico' in d:
            dettagli.append('pavimento_pelvico')
        if ('altro' in d) or ('utero' in d) or ('sacro' in d):
            dettagli.append('altro')
        infiltrazione_organi_dettagli_new.append(str(dettagli))
data_clean_guido.loc[:, 'infiltrazione_organi_dettagli'] = infiltrazione_organi_dettagli_new

#print(data_clean_guido.infiltrazione_organi_dettagli.value_counts())

# Sedi linfonodi
sedi_linfonodi_new = []
for s in data_clean_guido.sedi_linfonodi:
    sedi = ast.literal_eval(s)
    sedi_new = set()
    for sede in sedi:
        if sede in ['mesorettali', 'rettali_superiori', 'otturatori']:
            sedi_new.add(sede)
        elif sede in ['iliaci_comuni', 'iliaci_interni', 'iliaci_esterni']:
            sedi_new.add('iliaci')
        else:
            sedi_new.add('altro')
    sedi_linfonodi_new.append(str(list(sedi_new)))
data_clean_guido.loc[:, 'sedi_linfonodi'] = sedi_linfonodi_new
#print(data_clean_guido.sedi_linfonodi.value_counts())

# Coinvolgimento fascia mesorettale. Trasformiamo rischio in si
data_clean_guido.loc[data_clean_guido['coinvolgimento_fascia_mesorettale'] == 'rischio', 'coinvolgimento_fascia_mesorettale'] = 'si'
#print(data_clean_guido.coinvolgimento_fascia_mesorettale.value_counts())

# Coinvolgimento riflessione peritoneale. Trasformiamo rischio in si
data_clean_guido.loc[data_clean_guido['coinvolgimento_riflessione_peritoneale'] == 'rischio', 'coinvolgimento_riflessione_peritoneale'] = 'si'
#print(data_clean_guido.coinvolgimento_riflessione_peritoneale.value_counts())

# Infiltrazione sfinteri. Trasformiamo la posizione in si. per otenere una classe (si/no/NaN)
data_clean_guido.loc[data_clean_guido['infiltrazione_sfinteri'] == 'interno_piano', 'infiltrazione_sfinteri'] = 'si'
data_clean_guido.loc[data_clean_guido['infiltrazione_sfinteri'] == 'interno', 'infiltrazione_sfinteri'] = 'si'
data_clean_guido.loc[data_clean_guido['infiltrazione_sfinteri'] == 'interno_piano_esterno', 'infiltrazione_sfinteri'] = 'si'
#print(data_clean_guido.infiltrazione_sfinteri.value_counts())

# Emvi. Trasformiamo sospetto in si
data_clean_guido.loc[data_clean_guido['emvi_esteso'] == 'sospetto', 'emvi_esteso'] = 'si'
#print(data_clean_guido.emvi_esteso.value_counts())

# Depositi tumorali. Trasformiamo sospetto in si
data_clean_guido.loc[data_clean_guido['depositi_tumorali'] == 'sospetto', 'depositi_tumorali'] = 'si'
#print(data_clean_guido.depositi_tumorali.value_counts())

data_plot = data_clean_guido.fillna('NaN')

# %%
columns_plot = ['morfologia', 'infiltrazione_tessuto_adiposo', 'coinvolgimento_fascia_mesorettale',
                'carcinosi_peritoneale', 'riflessione_peritoneale_anteriore', 'coinvolgimento_riflessione_peritoneale',
                'stadio_T', 'stadio_N', 'stadio_N1c',
                'mrf', 'emvi', 'metastasi',
                'infiltrazione_sfinteri', 'infiltrazione_organi_extra',
                'linfonodi_sospetti', 'numero_linfonodi_non_conosciuto', 'lesioni_ossee',
                'depositi_tumorali', 'numero_depositi', 'emvi_esteso']

#hue_column = None
#columns_plot = [hue_column] + columns_plot

n_columns = 3
n_rows, r = divmod(len(columns_plot), n_columns)
if r != 0:
    n_rows += 1
    
fig, axes = plt.subplots(n_rows, n_columns, figsize=(n_columns*7, n_rows*3))
fig.suptitle("Count values (Guido)", fontsize='xx-large')

for i, col in enumerate(columns_plot):
    ax=axes[i//n_columns][i%n_columns]
    sns.countplot(data=data_plot, x=col, order=data_plot[col].value_counts().index, ax=ax, color=new_color)
    # Add values on top of bars
    for p in ax.patches:
        y_text = int(p.get_height())
        x_text = p.get_x() + p.get_width() / 2
        ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')

plt.tight_layout()
#plt.savefig("distribuzione_featurse_per_annotatore.png", dpi=300, bbox_inches='tight', transparent=False)
plt.show()

# %%
# Analisi posizione, sedi locoregionali, sedi non locoregionali
columns = ['posizione_multiple', 'sedi_locoregionali', 'sedi_non_locoregionali', 'sedi_linfonodi', 'infiltrazione_organi_dettagli']

possible_values = {col: ['NaN'] for col in columns}

for col in columns:
    for s in data_plot[col].value_counts().index:
        possible_values[col] += ast.literal_eval(s)
    possible_values[col] = list(set(possible_values[col]))    


counts = {
    col: {val: 0 for val in possible_values[col]}
    for col in columns
}
for col in columns:
    for s in data_plot[col]:
        value_list = ast.literal_eval(s)
        for value in possible_values[col]:
            if value in value_list:
                counts[col][value] += 1
        if value_list == []:
            counts[col]['NaN'] += 1
            
         
         
n_columns = 2
n_rows, r = divmod(len(columns), n_columns)
if r != 0:
    n_rows += 1
            
fig, axes = plt.subplots(n_rows, n_columns, figsize=(21, n_rows*3))
orientation = 'h'
for i, col in enumerate(columns):
    ax=axes[i//n_columns][i%n_columns]
    series = pd.Series(counts[col], name=col).sort_values(ascending=False)
    sns.barplot(data=series, ax=ax, orient=orientation, color=new_color)
    # Add values on top of bars
    if orientation == 'v':
        for p in ax.patches:
            y_text = int(p.get_height())
            x_text = p.get_x() + p.get_width() / 2
            ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')
    if orientation == 'h':
        for p in ax.patches:
            x_text = p.get_width()
            y_text = p.get_y() + p.get_height() / 2
            ax.text(x=x_text, y=y_text, s=f'{int(x_text)}', va='center', ha='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Colonne target numeriche

# %%
data_clean_guido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 46 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      144 non-null    int64
#  1   profile                                 144 non-null    object
#  2   discrepanze_rilevate                    144 non-null    object
#  3   motivazioni_discrepanze                 144 non-null    object
#  4   radiologist                             144 non-null    object
#  5   patient_id                              144 non-null    int64
#  6   sesso                                   143 non-null    object
#  7   data_nascita                            144 non-null    object
#  8   interpretazioni                         59 non-null     object
#  9   report_text                             144 non-null    object
#  10  morfologia                              143 non-null    object
#  11  ore_inizio                              57 non-null     float64
#  12  ore_fine                                57 non-null     float64
#  13  dimensione_dll                          12 non-null     float64
#  14  dimensione_dap                          9 non-null      float64
#  15  spessore_parietale                      25 non-null     float64
#  16  estensione_cranio_caudale               135 non-null    float64
#  17  distanza_oai                            132 non-null    float64
#  18  posizione                               97 non-null     object
#  19  posizione_multiple                      144 non-null    object
#  20  carcinosi_peritoneale                   1 non-null      object
#  21  lesioni_ossee                           2 non-null      object
#  22  stadio_T                                140 non-null    object
#  23  stadio_N                                143 non-null    object
#  24  stadio_N1c                              144 non-null    bool
#  25  mrf                                     55 non-null     object
#  26  emvi                                    28 non-null     object
#  27  metastasi                               7 non-null      object
#  28  motivazioni_extra                       144 non-null    object
#  29  riflessione_peritoneale_anteriore       89 non-null     object
#  30  infiltrazione_tessuto_adiposo           132 non-null    object
#  31  infiltrazione_sfinteri                  16 non-null     object
#  32  infiltrazione_organi_extra              142 non-null    object
#  33  infiltrazione_organi_dettagli           144 non-null    object
#  34  coinvolgimento_riflessione_peritoneale  26 non-null     object
#  35  coinvolgimento_fascia_mesorettale       57 non-null     object
#  36  distanza_minima_fascia_ore              7 non-null      float64
#  37  linfonodi_sospetti                      144 non-null    float64
#  38  numero_linfonodi_non_conosciuto         144 non-null    bool
#  39  sedi_locoregionali                      144 non-null    object
#  40  sedi_non_locoregionali                  144 non-null    object
#  41  depositi_tumorali                       79 non-null     object
#  42  numero_depositi                         143 non-null    float64
#  43  emvi_esteso                             144 non-null    object
#  44  status                                  144 non-null    object
#  45  sedi_linfonodi                          144 non-null    object
# dtypes: bool(2), float64(10), int64(2), object(32)
# memory usage: 49.9+ KB

# %%
colonne_target_numeriche = ['ore_inizio', 'ore_fine', 'dimensione_dll',
    'dimensione_dap', 'spessore_parietale', 'estensione_cranio_caudale',
    'distanza_oai', 'distanza_minima_fascia_ore',
    'linfonodi_sospetti', 'numero_depositi']

# %%
display(data_clean_guido[colonne_target_numeriche].describe().T)
display(data_clean_guido[colonne_target_numeriche].dtypes)
# Out:
#                             count       mean        std   min    25%   50%  \
# ore_inizio                   57.0   9.368421   3.538722   1.0   6.00  12.0
# ore_fine                     57.0  10.192982   3.492025   1.0  11.00  12.0
# dimensione_dll               12.0  42.250000  26.330504  15.0  21.50  40.0
# dimensione_dap                9.0  53.111111  32.643699  25.0  31.00  38.0
# spessore_parietale           25.0  20.280000  13.030477   7.0  13.00  15.0
# estensione_cranio_caudale   135.0  48.533333  17.460317  18.0  35.50  47.0
# distanza_oai                132.0  44.954545  29.293947   0.0  23.75  48.5
# distanza_minima_fascia_ore    7.0   6.000000   4.760952   1.0   2.00   5.0
# linfonodi_sospetti          144.0   0.638889   1.125739   0.0   0.00   0.0
# numero_depositi             143.0   0.055944   0.259366   0.0   0.00   0.0
#
#                               75%    max
# ore_inizio                  12.00   12.0
# ore_fine                    12.00   12.0
# dimensione_dll              49.75  105.0
# dimensione_dap              53.00  120.0
# spessore_parietale          22.00   60.0
# estensione_cranio_caudale   55.00  130.0
# distanza_oai                65.00  120.0
# distanza_minima_fascia_ore  10.00   12.0
# linfonodi_sospetti           1.00    4.0
# numero_depositi              0.00    2.0
# ore_inizio                    float64
# ore_fine                      float64
# dimensione_dll                float64
# dimensione_dap                float64
# spessore_parietale            float64
# estensione_cranio_caudale     float64
# distanza_oai                  float64
# distanza_minima_fascia_ore    float64
# linfonodi_sospetti            float64
# numero_depositi               float64
# dtype: object

# %% [markdown]
# escludere le segenti colonne perchè hanno troppi valori nulli:
# - dimensione_dll
# - dimensione_dap
# - distanza_minima_fascia_ore

# %%
n_columns = 5
n_rows, r = divmod(len(colonne_target_numeriche), n_columns)
if r != 0:
    n_rows += 1
    
fig, axes = plt.subplots(n_rows, n_columns, figsize=(21, n_rows*21/n_columns))
fig.suptitle("Numerical variables distribution", fontsize='xx-large')

for i, col in enumerate(colonne_target_numeriche):
    ax=axes[i//n_columns][i%n_columns]
    if len(data_clean_guido[col].value_counts()) > 5:
        sns.histplot(data=data_clean_guido, x=col, ax=ax, color=new_color, discrete=True, stat='count', kde=True)
    else:
        sns.countplot(data=data_clean_guido, x=col, order=data_clean_guido[col].value_counts().index, ax=ax, color=new_color)
        # Add values on top of bars
        for p in ax.patches:
            y_text = int(p.get_height())
            x_text = p.get_x() + p.get_width() / 2
            ax.text(x=x_text, y=y_text, s=f'{y_text}', ha='center', va='bottom')
plt.tight_layout()
plt.show()
