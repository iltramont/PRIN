# %%
import os
from openai import OpenAI
from dotenv import load_dotenv  
from pprint import pprint
from huggingface_hub import notebook_login, login

# %%
load_dotenv()  # Load environment variables from .env file

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 load_dotenv()  # Load environment variables from .env file
# ----> 3 client = OpenAI(
#       4     api_key=os.getenv("OPENAI_API_KEY")
#       5 )
#
# File c:\Users\lucat\VSCodeProjects\PRIN\.venv\Lib\site-packages\openai\_client.py:135, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     133     api_key = os.environ.get("OPENAI_API_KEY")
#     134 if api_key is None:
# --> 135     raise OpenAIError(
#     136         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     137     )
#     138 if callable(api_key):
#     139     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
response = client.responses.create(
    model="gpt-5",
    input="Write a one-sentence bedtime story about a unicorn."
)

print("*--- Response from OpenAI:")
print(response.output_text)
print("*--- Resopnse:")
pprint(response)
